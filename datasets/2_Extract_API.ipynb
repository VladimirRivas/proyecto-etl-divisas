# %%
import json

# 1. Cargar la configuración
# Reemplaza la ruta por la dirección real de tu archivo en el Repo
config_path = "/Workspace/Users/vladimir.rivas.yv@outlook.com/proyecto-etl-divisas/config/config_api.json"

with open(config_path, "r") as f:
    config = json.load(f)

# 2. Usar los datos del JSON
tickers = config["symbols"]
target_table = f"{config['storage']['catalog']}.{config['storage']['schema']}.{config['storage']['table']}"

print(f"✅ Configuración cargada. Procesando divisas: {tickers}")
